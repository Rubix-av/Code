# %% [markdown]
# Proramming Languagues used for Machine Learning
# 1. Python
# 2. R

# %% [markdown]
# #Print Function

# %%
print("Machine Learning" + "Practices")
# Out:
# Machine LearningPractices

# %%
print(8)
# Out:
# 8

# %% [markdown]
# #Basic Data Types
# 1. int
# 2. float
# 3. str

# %%
print("8 -> ", type(8))
print("8.4 -> ", type(8.4))
print("'8' -> ", type('8'))
# Out:
# 8 ->  <class 'int'>
# 8.4 ->  <class 'float'>
# '8' ->  <class 'str'>

# %% [markdown]
# #Constants and Variables

# %%
superhero = "Iron Man"
superhero = "Spider man"
print(superhero)
# Out:
# Spider man

# %% [markdown]
# #Input Function

# %%
number_1 = int(input("Enter the first number: "))
number_2 = int(input("Enter the second number: "))
sum = number_1 + number_2
print(sum)
# Out:
# Enter the first number: 23
# Enter the second number: 23
# 46
